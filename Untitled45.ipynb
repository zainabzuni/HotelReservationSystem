# %%
#define the Customer class
class Customer:
    def __init__(self, name, email, phone, address, loyalty_points=0):
        self.__name = name
        self.__email = email
        self.__phone = phone
        self.__address = address
        self.__loyalty_points = loyalty_points

    #getter methods
    def get_name(self):
        return self.__name

    def get_email(self):
        return self.__email

    def get_phone(self):
        return self.__phone

    def get_address(self):
        return self.__address

    def get_loyalty_points(self):
        return self.__loyalty_points

    #setter methods
    def set_name(self, name):
        self.__name = name

    def set_email(self, email):
        self.__email = email

    def set_phone(self, phone):
        self.__phone = phone

    def set_address(self, address):
        self.__address = address

    def set_loyalty_points(self, points):
        self.__loyalty_points = points

    #additional functions with 'pass' (to be implemented)
    def update_loyalty_points(self, points):
        pass

    def validate_customer_details(self):
        pass


#define the Reservation class
class Reservation:
    def __init__(self, reservation_id, room_type, check_in, check_out, total_cost):
        self.__reservation_id = reservation_id
        self.__room_type = room_type
        self.__check_in = check_in
        self.__check_out = check_out
        self.__total_cost = total_cost

    #getter methods
    def get_reservation_id(self):
        return self.__reservation_id

    def get_room_type(self):
        return self.__room_type

    def get_check_in(self):
        return self.__check_in

    def get_check_out(self):
        return self.__check_out

    def get_total_cost(self):
        return self.__total_cost

    #setter methods
    def set_reservation_id(self, reservation_id):
        self.__reservation_id = reservation_id

    def set_room_type(self, room_type):
        self.__room_type = room_type

    def set_check_in(self, check_in):
        self.__check_in = check_in

    def set_check_out(self, check_out):
        self.__check_out = check_out

    def set_total_cost(self, total_cost):
        self.__total_cost = total_cost

    #additional functions with 'pass' (to be implemented)
    def cancel_reservation(self):
        pass

    def modify_reservation(self, new_room_type=None, new_check_in=None, new_check_out=None):
        pass


#define the Room class
class Room:
    def __init__(self, room_number, room_type, is_available, price_per_night, amenities):
        self.__room_number = room_number
        self.__room_type = room_type
        self.__is_available = is_available
        self.__price_per_night = price_per_night
        self.__amenities = amenities

    #getter methods
    def get_room_number(self):
        return self.__room_number

    def get_room_type(self):
        return self.__room_type

    def get_is_available(self):
        return self.__is_available

    def get_price_per_night(self):
        return self.__price_per_night

    def get_amenities(self):
        return self.__amenities

    #setter methods
    def set_room_number(self, room_number):
        self.__room_number = room_number

    def set_room_type(self, room_type):
        self.__room_type = room_type

    def set_is_available(self, is_available):
        self.__is_available = is_available

    def set_price_per_night(self, price):
        self.__price_per_night = price

    def set_amenities(self, amenities):
        self.__amenities = amenities

    #additional functions with 'pass' (to be implemented)
    def check_availability(self):
        pass

    def reserve_room(self):
        pass


#define the Payment class
class Payment:
    def __init__(self, payment_id, payment_method, card_number, expiration_date, total_amount):
        self.__payment_id = payment_id
        self.__payment_method = payment_method
        self.__card_number = card_number
        self.__expiration_date = expiration_date
        self.__total_amount = total_amount

    #getter methods
    def get_payment_id(self):
        return self.__payment_id

    def get_payment_method(self):
        return self.__payment_method

    def get_card_number(self):
        return self.__card_number

    def get_expiration_date(self):
        return self.__expiration_date

    def get_total_amount(self):
        return self.__total_amount

    #setter methods
    def set_payment_id(self, payment_id):
        self.__payment_id = payment_id

    def set_payment_method(self, payment_method):
        self.__payment_method = payment_method

    def set_card_number(self, card_number):
        self.__card_number = card_number

    def set_expiration_date(self, expiration_date):
        self.__expiration_date = expiration_date

    def set_total_amount(self, total_amount):
        self.__total_amount = total_amount

    #additional functions with 'pass' (to be implemented)
    def process_payment(self):
        pass

    def validate_payment(self):
        pass


#example usage
customer = Customer("Zainab Abdullah", "zainababdullah@gmail.com", "05012345678", "Dubai, UAE")
reservation = Reservation("789456123", "1 King Bed", "2024-10-01", "2024-10-03", 250.75)
room = Room("202", "1 King Bed", True, 125.37, "Wi-Fi, TV, Mini-bar")
payment = Payment("456789123", "Visa", "1234567891234567", "11/12", 250.75)

#display information
print(f"Customer: {customer.get_name()}")
print(f"Room Type: {reservation.get_room_type()}")
print(f"Check-In Date: {reservation.get_check_in()}")
print(f"Total Cost: {reservation.get_total_cost()}")
# Out:
# Customer: Zainab Abdullah
# Room Type: 1 King Bed
# Check-In Date: 2024-10-01
# Total Cost: 250.75
